# %%
# !unzip "/content/Dataset.zip" -d "/content/"
# Out:
# Archive:  /content/Dataset.zip
#    creating: /content/Dataset/
#    creating: /content/Dataset/Images/
#    creating: /content/Dataset/Images/test/
#   inflating: /content/Dataset/Images/test/05ff01fa-20250108-115407401.jpg
#   inflating: /content/Dataset/Images/test/124e696d-20240914-105651782.jpg
#   inflating: /content/Dataset/Images/test/1459fc45-20240831-113821806.jpg
#   inflating: /content/Dataset/Images/test/18fd6ab8-20250415-143542497.jpg
#   inflating: /content/Dataset/Images/test/1b000dc7-20240813-115604759.jpg
#   inflating: /content/Dataset/Images/test/448a529c-20240810-121007744.jpg
#   inflating: /content/Dataset/Images/test/4a54fcae-20240808-115419598.jpg
#   inflating: /content/Dataset/Images/test/52ca82f2-20241206-111446878.jpg
#   inflating: /content/Dataset/Images/test/5b9cbf85-20240620-151246826.jpg
#   inflating: /content/Dataset/Images/test/73b95a6f-20240909-115239356.jpg
#   inflating: /content/Dataset/Images/test/7e07ad10-20240819-103441968.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 37.9 MB/s eta 0:00:00
# ...

# %%
# !yolo detect train data=/content/data.yaml model=yolov8s.pt imgsz=640 epochs=100 batch=16
# Out:
# Ultralytics 8.3.189 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect predict model=runs/detect/train4/weights/best.pt source=/content/Dataset/images/test save=True
# Out:
# Ultralytics 8.3.189 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,137,968 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/50 /content/Dataset/images/test/05ff01fa-20250108-115407401.jpg: 640x640 1 Canine (13), 1 Canine (23), 1 Canine (33), 1 Canine (43), 1 Central Incisor (21), 1 Central Incisor (41), 1 Central Incisor (31), 1 Central Incisor (11), 1 First Molar (16), 1 First Molar (26), 1 First Molar (36), 1 First Molar (46), 1 First Premolar (14), 1 First Premolar (34), 1 First Premolar (44), 1 First Premolar (24), 1 Lateral Incisor (22), 1 Lateral Incisor (32), 1 Lateral Incisor (42), 1 Lateral Incisor (12), 1 Second Molar (17), 1 Second Molar (27), 1 Second Molar (37), 1 Second Molar (47), 1 Second Premolar (15), 1 Second Premolar (25), 1 Second Premolar (35), 1 Second Premolar (45), 1 Third Molar (18), 1 Third Molar (28), 1 Third Molar (38), 1 Third Molar (48), 16.4ms
# ...

# %%
# !zip -r /content/runs_folder.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/predict/ (stored 0%)
#   adding: content/runs/detect/predict/cate9-00022_jpg.rf.bed596edcecf1f2b424a5741e3bb6806.jpg (deflated 2%)
#   adding: content/runs/detect/predict/cate5-00018_jpg.rf.c1be210fbd78cfab825faf0c792ce7ac.jpg (deflated 3%)
#   adding: content/runs/detect/predict/b94abb31-20250429-142751426.jpg (deflated 2%)
#   adding: content/runs/detect/predict/cate8-00437_jpg.rf.698a3864a8332510783110161c0a0479.jpg (deflated 3%)
#   adding: content/runs/detect/predict/cate7-00032_jpg.rf.fc1e4fb732ca24041661d1e805432319.jpg (deflated 3%)
#   adding: content/runs/detect/predict/cate2-00124_jpg.rf.98cc5484a96e6c818f2e60958081f51d.jpg (deflated 3%)
#   adding: content/runs/detect/predict/a8792134-20240729-155643000.jpg (deflated 2%)
#   adding: content/runs/detect/predict/cate8-00051_jpg.rf.7fdaa8b122b04dd8bc3fec51b2434902.jpg (deflated 3%)
# ...
